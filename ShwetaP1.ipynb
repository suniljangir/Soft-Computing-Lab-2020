# %% [markdown]
# <a href="https://colab.research.google.com/github/shwetay58/Soft-Computing-Lab-2020/blob/master/ShwetaP1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# AIM: A program to implement all operators in python

# %% [markdown]
# 1. Arithematic Operators

# %%
#Addition
x = 10
y = 5
print('x + y =',x+y)

# Substraction
print('x - y =',x-y)

# Multiplication
print('x * y =',x*y)

# Division
print('x / y =',x/y)

# Floor division
print('x // y =',x//y)

# Exponent
print('x ** y =',x**y)

# Modulus
print('x % y =',x%y)
# Out:
# x + y = 15
# x - y = 5
# x * y = 50
# x / y = 2.0
# x // y = 2
# x ** y = 100000
# x % y = 0

# %% [markdown]
# 2. Comparison Operators

# %%
x = 2
y = 3

# Greater than
print('x > y is',x>y)

# Less than
print('x < y is',x<y)

# Equal to
print('x == y is',x==y)

# Not equal to
print('x != y is',x!=y)

# Greater than or equal to
print('x >= y is',x>=y)

# Smaller than or equal to
print('x <= y is',x<=y)
# Out:
# x > y is False
# x < y is True
# x == y is False
# x != y is True
# x >= y is False
# x <= y is True

# %% [markdown]
# 3. Logical Operators

# %%
x = True #considered as 1
y = False #considered as 0

print('x or y is',x or y)

print('x and y is',x and y)

print('not x is',not x)
# Out:
# x or y is True
# x and y is False
# not x is False

# %% [markdown]
# 4. Bitwise Operators

# %%
x = 2
y = 8

# Bitwise AND
print(x & y)

# Bitwise OR
print(x | y)

# Bitwise NOT
print(~x)

# Bitwise XOR
print(x ^ y)

# Bitwise RIGHT SHIFT
print(x >> 2)

# Bitwise LEFT SHIFT
print(x << 2)
# Out:
# 0
# 10
# -3
# 10
# 0
# 8

# %% [markdown]
# 5. Assignment Operators

# %%
a = 11
b = 3
c = 30

c = a + b
print ("Value of c after c = a + b is ", c)

c += a
print ("Value of c after c += a is ", c )

c *= a
print ("Value of c after c *= a is ", c)

c /= a 
print ("Value of c after c /= a  is ", c) 

c  = 2
c %= a
print ("Value of c after c %= a is ", c)

c **= a
print ("Value of c after c **= a is ", c)

c //= a
print ("Value of c after c //= a is ", c)
# Out:
# Value of c after c = a + b is  14
# Value of c after c += a is  25
# Value of c after c *= a is  275
# Value of c after c /= a  is  25.0
# Value of c after c %= a is  2
# Value of c after c **= a is  2048
# Value of c after c //= a is  186
