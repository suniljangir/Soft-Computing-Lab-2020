# %% [markdown]
# AIM: Create plots

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# y=e^ax

# %%
x = np.linspace(-10, 10, 100) 
a=np.random.random()
y = np.exp(a*x)
fig = plt.figure(figsize = (10,5)) 
plt.grid(alpha =.7, linestyle ='--') 
plt.xlabel('x axis') 
plt.ylabel('y axis') 
plt.plot(x,y,'m',linewidth=2)
plt.show()

# %% [markdown]
#  y=7x^2 + 3x + 10 for 2<=x<=5

# %%
x = np.linspace(2, 5, 100) #using 100 points to draw the plot
y = 7*x**2 + 3*x + 10  
fig = plt.figure(figsize = (10, 5)) 
plt.plot(x, y,'r',alpha=0.8,linestyle ='-.') # Create the plot
plt.grid(alpha =.7, linestyle ='--') 
plt.xlabel('x axis') 
plt.ylabel('y axis') 
plt.show() # Show the plot

# %% [markdown]
#  y=1/1+e^-x

# %%
x = np.linspace(-5, 5, 100) 
y = 1/(1+np.exp(-x))
fig = plt.figure(figsize = (10,5)) 
plt.plot(x,y,'y',linestyle='-')
plt.grid(alpha =.7, linestyle ='--') 
plt.xlabel('x axis') 
plt.ylabel('y axis') 
plt.show()

# %% [markdown]
# y=1-e^-ax/1+e^ax for different values of a

# %%
import random
x = np.linspace(-30, 30, 100) 
a=np.random.random()
y = (1-np.exp(-a*x))/(1+np.exp(-a*x))
fig = plt.figure(figsize = (10,5)) 
plt.grid(alpha =.7, linestyle ='--') 
plt.xlabel('x axis') 
plt.ylabel('y axis') 
plt.plot(x,y,'g')
plt.show()

# %% [markdown]
# y=tanhx

# %%
x = np.linspace(-6, 6, 50)   
y = np.tanh(x) 
fig = plt.figure(figsize = (10,5)) 
plt.plot(x,y,'c',linestyle='-',linewidth=2)
plt.grid(alpha =.7, linestyle ='-') 
plt.xlabel('x axis') 
plt.ylabel('y axis') 
plt.show()
