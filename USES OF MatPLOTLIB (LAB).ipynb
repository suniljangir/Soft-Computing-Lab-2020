# %%
from matplotlib import pyplot as plt

#plotting to our canvas
plt.plot([1,2,3],[4,5,1])
#showing what a plotted
plt.show()

# %%
import numpy as np
plt.plot([1,2,3,4],[1,4,9,16],'r1',label='line1')  #draw red dots 
plt.plot([1,2,3,4],[1,2,3,4],linewidth=5,label='line2') #thickness of line
plt.plot([5,6,7,8,9],[5,6,7,8,9],'ro-',label='line3')  #points will b like o
plt.plot([5,6,7,8,9],[6,6,6,6,6],color='red',linestyle="-",marker='o',markersize='5',markerfacecolor='g') 
#[xmin,xmax,ymin,ymax]
plt.axis([0,10,0,20])
plt.show()

t=np.arange(0,5,.2)
plt.plot(t,t,'r--',t,t**2,'bo',t,t**4,'c^')  #c is the color and ^ is the shape
# Out:
# [<matplotlib.lines.Line2D at 0x273247b14a8>,
#  <matplotlib.lines.Line2D at 0x273247b16a0>,
#  <matplotlib.lines.Line2D at 0x273247b19e8>]

# %%
x=[5,2,7]
y=[2,16,4]
plt.plot(x,y) #plt.plot(x,y,linewidth=5,color='red')
plt.title('Info')
plt.ylabel('Y axis')
plt.xlabel('X axis')
plt.show()

# %%
x=[5,8,10]
y=[12,16,6]
x2=[6,9,11]
y2=[6,15,7]
plt.plot(x,y,'g',label='line one',linewidth=5)
plt.plot(x2,y2,'c',label='line two',linewidth=5)
plt.title("Epic Info")
plt.ylabel('Y axis')
plt.xlabel('X axis')
plt.legend() #give the labels
plt.grid(True,color='k')
plt.show()

# %% [markdown]
# # bargraph: compare two entities

# %%
plt.bar([0.25,1.25,2.25,3.25,4.25],[50,40,70,80,20],label="BMW",width=.3)
plt.bar([.75,1.75,2.75,3.75,4.75],[80,20,20,50,60],label="Audi",color='c',width=.5)
plt.legend()
plt.xlabel('Days')
plt.ylabel('Distance (kms)')
plt.title('Information')
plt.show()

# %% [markdown]
# # histogram: show distribution and used to plot frequency

# %%
population_age=[44,22,77,44,22,99,55,22,77,99,44,22,77,55,55]
bins= np.arange(1,100)  #we give the range of x axis and it automatically taake y axis
plt.hist(population_age,bins,histtype='bar',rwidth=0.8)
plt.xlabel('age grp')
plt.ylabel('Number of people')
plt.title('Histogram')
plt.show()

# %% [markdown]
# # scatter plot: plot points

# %%
x=[1,1.5,2,2.5,3,3.5,3.6]
y=[7.5,8,8.5,9,9.5,10,10.5]

x1=[8,8.5,9,9.5,10,10.5,11]
y1=[3,3.5,3.7,4,4.5,5,5.2]

plt.scatter(x,y,label='high income low saving',color='r')
plt.scatter(x1,y1,label='low income high saving',color='b')
plt.xlabel('saving*100')
plt.ylabel('income*1000')
plt.title('Scatter Plot')
plt.legend()
plt.show()

# %% [markdown]
# # area plot

# %%
days=[1,2,3,4,5]
sleeping=[6,7,8,9,10]
eating=[2,3,4,3,2]
working=[7,8,7,2,2]
playing=[8,5,7,8,13]

plt.plot([],[],color='m',label="sleeping",linewidth=5)  #[][]show 2d array
plt.plot([],[],color='c',label="eating",linewidth=5)
plt.plot([],[],color='r',label="working",linewidth=5)
plt.plot([],[],color='k',label="playing",linewidth=5)

plt.stackplot(days,sleeping,eating,working,playing,colors=['m','c','r','k'])

plt.xlabel('x')
plt.ylabel('y')
plt.title('stack plot')
plt.legend()
plt.show()

# %%
days=[1,2,3,4,5]
sleeping=[6,7,8,9,10]
eating=[2,3,4,3,2]
working=[7,8,7,2,2]
playing=[8,5,7,8,13]
slices=[7,2,2,13]
activities=['sleeping','eating','working','playing']
cols=['c','m','r','b']

plt.pie(slices,labels=activities,colors=cols,startangle=90,shadow=True,explode=(0,0.1,0,0),autopct='%1.1f%%')

plt.title('Pie Plot')
plt.show()

# %% [markdown]
# # Multiple plots

# %%
def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)
t1=np.arange(0.0,5.0,0.1)
t2=np.arange(0.0,5.0,0.02)
plt.subplot(211)  #first one show that there are 2 plots , second show that the plot are represented row wise or coloumn wise,third one show that 
#this is first/second plot
plt.plot(t1,f(t1),'bo',t2,f(t2))
plt.subplot(212)
plt.plot(t2,np.cos(2*np.pi*t2))
plt.show()

# %%
def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)
t1=np.arange(0.0,5.0,0.1)
t2=np.arange(0.0,5.0,0.02)
plt.subplot(222)  #first one show that there are 2 plots , second show that the plot are represented rowise,third one show that 
#this is first/second plot
plt.plot(t1,f(t1),'bo',t2,f(t2))
plt.subplot(221)
plt.plot(t2,np.cos(2*np.pi*t2))
plt.show()

# %%
#compute the x and y coordinates  for points on a sine curve
x=np.arange(0,3*np.pi,0.1)
y=np.sin(x)
#plot the points using matplotlib
plt.plot(x,y)
plt.show()
