# %% [markdown]
# <a href="https://colab.research.google.com/github/arunima27-3-99/Soft-Computing-Lab-2020/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=5
b=9
c=a+b #addition
print(c)
# Subtraction
d=b-a
print(d)
# Multiplication
e=a*b
print(b)
#Division
f=b/a
print(f)
#Modulus
print(a%b)
#Exponent
print(a**b)
#Floor Division
print(a//b)
# Out:
# 14
# 4
# 9
# 1.8
# 5
# 1953125
# 0

# %%
print(a==b) 
print(a!=b) 
print(a>b)
print(a<b)
print(a>=b)
print(a<=b)
# Out:
# False
# True
# False
# True
# False
# True

# %%
print(a&b)
print(a|b)
print(a^b)
print(~a)
print(a<<1)
print(a>>1)
# Out:
# 1
# 13
# 12
# -6
# 10
# 2

# %%
print(a>7 and b<7)
print(a>7 or b<7)
print(not(a>7))
# Out:
# False
# False
# True

# %%
c=a+b
print(c)
c+=a
print(c)
c-=a
print(c)
c*=a
print(c)
c/=a
print(c)
c**=a
print(c)
c%=a
print(c)
c//=a
print(c)
# Out:
# 14
# 19
# 14
# 70
# 14.0
# 537824.0
# 4.0
# 0.0

# %%
print(a is b)
print(a is not b)
# Out:
# False
# True
