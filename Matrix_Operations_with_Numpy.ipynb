# %% [markdown]
# <a href="https://colab.research.google.com/github/ISHIKA10/Soft-Computing-Lab-2020/blob/patch-1/Matrix_Operations_with_Numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
a= np.array([[1,2,3],[5,6,7],[8,9,0]])
b=np.array([[0,1,0],[1,1,1],[2,2,2]])

# %%
# to add two matrices:
ad= np.add(a,b)
ad
# Out:
# array([[ 1,  3,  3],
#        [ 6,  7,  8],
#        [10, 11,  2]])

# %%
# to subtract two matrices:
su= np.subtract(a,b)
su
# Out:
# array([[ 1,  1,  3],
#        [ 4,  5,  6],
#        [ 6,  7, -2]])

# %%
# to divide two matrices:
di= np.divide(a,b)
di
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in true_divide
# array([[inf, 2. , inf],
#        [5. , 6. , 7. ],
#        [4. , 4.5, 0. ]])

# %%
# to multiply two matrices:
mul=np.dot(a,b)
mul
# Out:
# array([[ 8,  9,  8],
#        [20, 25, 20],
#        [ 9, 17,  9]])

# %%
mul2= np.multiply(a,b)
mul2
# Out:
# array([[ 0,  2,  0],
#        [ 5,  6,  7],
#        [16, 18,  0]])

# %%
# to  do sqaureroot 
s=np.sqrt(a)
s
# Out:
# array([[1.        , 1.41421356, 1.73205081],
#        [2.23606798, 2.44948974, 2.64575131],
#        [2.82842712, 3.        , 0.        ]])

# %%
# the summation of elements:
o=np.sum(b)
o
# Out:
# 10

# %%
# row wise summation 
r= np.sum(a,axis=1)
r
# Out:
# array([ 6, 18, 17])

# %%
# col wise summation 
c= np.sum(a,axis=0)
c
# Out:
# array([14, 17, 10])

# %%
#matrix transpose
t= a.T
t
# Out:
# array([[1, 5, 8],
#        [2, 6, 9],
#        [3, 7, 0]])
